# %%
# !git pull
# Out:
# Already up to date.

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\admin\\Desktop\\Year two'

# %%
os.chdir(r"C:\Users\admin\Desktop\Year two\ML project\croprecommendationproject")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\admin\\Desktop\\Year two\\ML project\\croprecommendationproject'

# %%
#!pip install xgboost

# %%
import pandas as pd
import numpy as np
import os
import sys
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (accuracy_score, classification_report, confusion_matrix, precision_score, recall_score)
os.chdir("..")
print(os.getcwd())
sys.path.append(os.path.abspath(".."))
# Out:
# C:\Users\admin\Desktop\Year two

# %%
"""
X = df.drop("label", axis=1)
y = df["label"]

# XGBoost needs numbers, so we encoded the crop names
le = LabelEncoder()  #the tool converting numbers to words
y_encoded = le.fit_transform(y)   #assigns each crop a number and implements it 

print("Crops found:", le.classes_)
print("Number of crops:", len(le.classes_))
"""

# %%
"""
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42
)

print("Training samples:", X_train.shape[0])
print("Testing samples:", X_test.shape[0])
"""

# %%
from src.preprocessing import CropPreprocessor

preprocessor = CropPreprocessor()

data = preprocessor.preprocess("data/raw/Crop_recommendation.csv")

# %%
X_train = data["X_train"]
X_test = data["X_test"]
y_train = data["y_train"]
y_test = data["y_test"]

# %%
#Training thje XGboost
model = XGBClassifier(
    n_estimators=100, #100 trees, each learning from the previous' mistake
    learning_rate=0.1, #how fast the model runs
    max_depth=6,  #deeper means more complex pattern and risk of overfitting
    eval_metric="mlogloss",  #metric that calculates how acurately the predicted prob match the actual class labels
    random_state=42 #makes results reproducible
)

model.fit(X_train, y_train) #the actual learning
print("Model trained successfully!")
# Out:
# Model trained successfully!

# %%
#classification report function
def classification_metrics(y_actual, y_pred):
    acc = round(accuracy_score(y_actual, y_pred)*100, 2)  #how correct the model is
    precision = round(precision_score(y_actual, y_pred, average="weighted")*100, 2) #reputability
    recall = round(recall_score(y_actual, y_pred, average="weighted")*100, 2) #how well it finds the actual positives
    cm = confusion_matrix(y_actual, y_pred)
    return acc, precision, recall, cm

# %%
#evaluate the model
y_pred = model.predict(X_test) #predictions using the test data

acc, precision, recall, cm = classification_metrics(y_test, y_pred)

# Print results in percentage
print(f"Accuracy:  {acc}%")
print(f"Precision: {precision}%")
print(f"Recall:    {recall}%")
# Out:
# Accuracy:  98.86%
# Precision: 98.94%
# Recall:    98.86%

# %%
print(y_train)
# Out:
# [16  7  9 ...  8  8  7]

# %%
#confusion matrix
plt.figure(figsize=(12, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="RdPu",  #annot is to show the numbers inside the cell and fmt is formatting to decimal
            xticklabels=model.classes_, #label with crop names instead of numbers
            yticklabels=model.classes_)
plt.title("Confusion Matrix for XGBoost: Crop Recommendation System")
plt.xlabel("Predicted Crop")
plt.ylabel("Actual Crop")
plt.xticks(rotation=45) #prevents overlapping of the crops
plt.tight_layout() #adjusts spacing
plt.show()

# %%
print(data.keys())  #to check exactly what's in the preprocessor array
# Out:
# dict_keys(['X_train', 'X_test', 'y_train', 'y_test', 'scaler', 'label_encoder', 'feature_names'])

# %%
#feature importance plot
feature_names = data["feature_names"]

feat_importance = pd.Series(model.feature_importances_, index=feature_names)  #calculating how much each feature contributed to making correct predictions
feat_importance.sort_values().plot(kind="bar", figsize=(8, 5), color="pink") #barh = horizontal bar graph
plt.title("Feature Importance - XGBoost")
plt.ylabel("Importance Score")
plt.xlabel("Features")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Testing
"""sample = pd.DataFrame([{
    "N": 90, "P": 42, "K": 43,
    "temperature": 20.8,
    "humidity": 82.0,
    "ph": 6.5,
    "rainfall": 202.9
}])

probabilities = model.predict_proba(sample)[0]  # getting probabilities for all 22 crops


crop_probs = pd.Series(probabilities, index=le.classes_)  # linking each crop name to its probability


top3 = crop_probs.sort_values(ascending=False).head(3)  # sort and get top 3


print("Top 3 Recommended Crops:")
for i, (crop, prob) in enumerate(top3.items(), 1):
    print(f"{i}. {crop} — {round(prob*100, 2)}%")"""
# Out:
# 'sample = pd.DataFrame([{\n    "N": 90, "P": 42, "K": 43,\n    "temperature": 20.8,\n    "humidity": 82.0,\n    "ph": 6.5,\n    "rainfall": 202.9\n}])\n\nprobabilities = model.predict_proba(sample)[0]  # getting probabilities for all 22 crops\n\n\ncrop_probs = pd.Series(probabilities, index=le.classes_)  # linking each crop name to its probability\n\n\ntop3 = crop_probs.sort_values(ascending=False).head(3)  # sort and get top 3\n\n\nprint("Top 3 Recommended Crops:")\nfor i, (crop, prob) in enumerate(top3.items(), 1):\n    print(f"{i}. {crop} — {round(prob*100, 2)}%")'

# %%
le = data["label_encoder"]
scaler = data["scaler"]

sample = pd.DataFrame([{
    "N": 90, "P": 42, "K": 43,
    "temperature": 20.8,
    "humidity": 82.0,
    "ph": 6.5,
    "rainfall": 202.9
}])

sample_scaled = scaler.transform(sample)

probabilities = model.predict_proba(sample_scaled)[0]
crop_probs = pd.Series(probabilities, index=le.classes_)
top3 = crop_probs.sort_values(ascending=False).head(3)

print("Top 3 Recommended Crops:")
for i, (crop, prob) in enumerate(top3.items(), 1):
    print(f"{i}. {crop} — {round(prob*100, 2)}%")
# Out:
# Top 3 Recommended Crops:
# 1. rice — 99.53%
# 2. jute — 0.12%
# 3. coffee — 0.04%

# %%
#!git add .
#!git commit -m "updated the model to use the preprocessing file"
# !git push
# Out:
# To https://github.com/TINOZOERAMONA/croprecommendationproject.git
#    9303b14..d9f2a00  main -> main
